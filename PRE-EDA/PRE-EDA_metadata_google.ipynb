# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from collections import Counter

# %%
#Funcion para imprimir un ejemplo no nulo de cada variable
def imprimir_ejemplos(df):
    ejemplo = []
    titulo = []
    tipo = []
    global titulos
    global tipos
    for elemento in df.columns:
        for valor in df[elemento]:
            flag = 0
            while valor != None:
                ejemplo.append(valor)
                titulo.append(elemento)
                tipo.append(type(valor))
                flag = 1
                break
            if flag == 1:
                break
    titulos.append(titulo)
    tipos.append(tipo)
    for i in range(len(ejemplo)):
        print(titulo[i], ': ', ejemplo[i])
        print('Tipo de dato: ', tipo[i])
        print()

# %%
#Nombre de la carpeta donde estan alojados los archivos
carpeta = 'C:/Users/eduen/Desktop/PF_Yelp-Maps_DS-04pt/metadata_google'

#En lista_df se carga cada dataframe para luego concatenarlos
lista_df = []

#Titulos y tipos cargan por cada dataframe una lista con los nombres de las columnas y el tipo de dato de cada una
#Se van a Utilizar para comparar que sean equivalentes en todos los df tanto los nombres como los tipos de dato
titulos = []
tipos = []

#Este for itera por los nombres de los archivos dentro de la carpeta
for archivo in os.listdir(carpeta):
   
    df = pd.read_json(f'{carpeta}/{archivo}', lines=True)#Carga el df
    lista_df.append(df)#Lo guarda en la lista para concatenar

    print(f'ANALISIS PRELIMINAR DATASET: {archivo}')
    print()
    print('EJEMPLOS NO NULOS:')
    print()
    display(imprimir_ejemplos(df))#Imprime el primer dato NO NULO de cada columna y el tipo de dato del mismo
# Out:
# ANALISIS PRELIMINAR DATASET: 1.json
#
# EJEMPLOS NO NULOS:
#
# name :  Porter Pharmacy
# Tipo de dato:  <class 'str'>
#
# address :  Porter Pharmacy, 129 N Second St, Cochran, GA 31014
# Tipo de dato:  <class 'str'>
#
# gmap_id :  0x88f16e41928ff687:0x883dad4fd048e8f8
# Tipo de dato:  <class 'str'>
#
# description :  Chain selling interior & exterior paints, primers & finishes, plus supplies.
# Tipo de dato:  <class 'str'>
#
# latitude :  32.3883
# Tipo de dato:  <class 'float'>
#
# longitude :  -83.3571
# Tipo de dato:  <class 'float'>
#
# category :  ['Pharmacy']
# Tipo de dato:  <class 'list'>
#
# avg_rating :  4.9
# Tipo de dato:  <class 'float'>
#
# num_of_reviews :  16
# Tipo de dato:  <class 'int'>
#
# price :  $
# Tipo de dato:  <class 'str'>
#
# hours :  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM'], ['Sunday', 'Closed'], ['Monday', '8AM–6PM'], ['Tuesday', '8AM–6PM'], ['Wednesday', '8AM–12PM'], ['Thursday', '8AM–6PM']]
# Tipo de dato:  <class 'list'>
#
# MISC :  {'Service options': ['In-store shopping', 'Same-day delivery'], 'Health & safety': ['Mask required', 'Staff required to disinfect surfaces between visits'], 'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Quick visit']}
# Tipo de dato:  <class 'dict'>
#
# state :  Open ⋅ Closes 6PM
# Tipo de dato:  <class 'str'>
#
# relative_results :  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x88f16c32716531c1:0x5f19bdaa5044e4fa', '0x88f16e6e3f4a21df:0xcf495da9bb4d89ea']
# Tipo de dato:  <class 'list'>
#
# url :  https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us
# Tipo de dato:  <class 'str'>
# None
# ANALISIS PRELIMINAR DATASET: 10.json
#
# EJEMPLOS NO NULOS:
#
# name :  Porter Pharmacy
# Tipo de dato:  <class 'str'>
#
# address :  Porter Pharmacy, 129 N Second St, Cochran, GA 31014
# Tipo de dato:  <class 'str'>
#
# gmap_id :  0x88f16e41928ff687:0x883dad4fd048e8f8
# Tipo de dato:  <class 'str'>
#
# description :  Retail chain with a variety of Western & work-related apparel, shoes & accessories, plus gifts.
# Tipo de dato:  <class 'str'>
#
# latitude :  32.3883
# Tipo de dato:  <class 'float'>
#
# longitude :  -83.3571
# Tipo de dato:  <class 'float'>
#
# category :  ['Pharmacy']
# Tipo de dato:  <class 'list'>
#
# avg_rating :  4.9
# Tipo de dato:  <class 'float'>
#
# num_of_reviews :  16
# Tipo de dato:  <class 'int'>
#
# price :  $
# Tipo de dato:  <class 'str'>
#
# hours :  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM'], ['Sunday', 'Closed'], ['Monday', '8AM–6PM'], ['Tuesday', '8AM–6PM'], ['Wednesday', '8AM–12PM'], ['Thursday', '8AM–6PM']]
# Tipo de dato:  <class 'list'>
#
# MISC :  {'Service options': ['In-store shopping', 'Same-day delivery'], 'Health & safety': ['Mask required', 'Staff required to disinfect surfaces between visits'], 'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Quick visit']}
# Tipo de dato:  <class 'dict'>
#
# state :  Open ⋅ Closes 6PM
# Tipo de dato:  <class 'str'>
#
# relative_results :  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x88f16c32716531c1:0x5f19bdaa5044e4fa', '0x88f16e6e3f4a21df:0xcf495da9bb4d89ea']
# Tipo de dato:  <class 'list'>
#
# url :  https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us
# Tipo de dato:  <class 'str'>
# None
# ANALISIS PRELIMINAR DATASET: 11.json
#
# EJEMPLOS NO NULOS:
#
# name :  Porter Pharmacy
# Tipo de dato:  <class 'str'>
#
# address :  Porter Pharmacy, 129 N Second St, Cochran, GA 31014
# Tipo de dato:  <class 'str'>
#
# gmap_id :  0x88f16e41928ff687:0x883dad4fd048e8f8
# Tipo de dato:  <class 'str'>
#
# description :  Trendy, upscale retailer offering designer apparel, urbanwear, shoes & accessories for all ages.
# Tipo de dato:  <class 'str'>
#
# latitude :  32.3883
# Tipo de dato:  <class 'float'>
#
# longitude :  -83.3571
# Tipo de dato:  <class 'float'>
#
# category :  ['Pharmacy']
# Tipo de dato:  <class 'list'>
#
# avg_rating :  4.9
# Tipo de dato:  <class 'float'>
#
# num_of_reviews :  16
# Tipo de dato:  <class 'int'>
#
# price :  $
# Tipo de dato:  <class 'str'>
#
# hours :  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM'], ['Sunday', 'Closed'], ['Monday', '8AM–6PM'], ['Tuesday', '8AM–6PM'], ['Wednesday', '8AM–12PM'], ['Thursday', '8AM–6PM']]
# Tipo de dato:  <class 'list'>
#
# MISC :  {'Service options': ['In-store shopping', 'Same-day delivery'], 'Health & safety': ['Mask required', 'Staff required to disinfect surfaces between visits'], 'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Quick visit']}
# Tipo de dato:  <class 'dict'>
#
# state :  Open ⋅ Closes 6PM
# Tipo de dato:  <class 'str'>
#
# relative_results :  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x88f16c32716531c1:0x5f19bdaa5044e4fa', '0x88f16e6e3f4a21df:0xcf495da9bb4d89ea']
# Tipo de dato:  <class 'list'>
#
# url :  https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us
# Tipo de dato:  <class 'str'>
# None
# ANALISIS PRELIMINAR DATASET: 2.json
#
# EJEMPLOS NO NULOS:
#
# name :  Porter Pharmacy
# Tipo de dato:  <class 'str'>
#
# address :  Porter Pharmacy, 129 N Second St, Cochran, GA 31014
# Tipo de dato:  <class 'str'>
#
# gmap_id :  0x88f16e41928ff687:0x883dad4fd048e8f8
# Tipo de dato:  <class 'str'>
#
# description :  Family-owned clothing chain offering trendy casualwear, shoes & accessories for adults & kids.
# Tipo de dato:  <class 'str'>
#
# latitude :  32.3883
# Tipo de dato:  <class 'float'>
#
# longitude :  -83.3571
# Tipo de dato:  <class 'float'>
#
# category :  ['Pharmacy']
# Tipo de dato:  <class 'list'>
#
# avg_rating :  4.9
# Tipo de dato:  <class 'float'>
#
# num_of_reviews :  16
# Tipo de dato:  <class 'int'>
#
# price :  $
# Tipo de dato:  <class 'str'>
#
# hours :  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM'], ['Sunday', 'Closed'], ['Monday', '8AM–6PM'], ['Tuesday', '8AM–6PM'], ['Wednesday', '8AM–12PM'], ['Thursday', '8AM–6PM']]
# Tipo de dato:  <class 'list'>
#
# MISC :  {'Service options': ['In-store shopping', 'Same-day delivery'], 'Health & safety': ['Mask required', 'Staff required to disinfect surfaces between visits'], 'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Quick visit']}
# Tipo de dato:  <class 'dict'>
#
# state :  Open ⋅ Closes 6PM
# Tipo de dato:  <class 'str'>
#
# relative_results :  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x88f16c32716531c1:0x5f19bdaa5044e4fa', '0x88f16e6e3f4a21df:0xcf495da9bb4d89ea']
# Tipo de dato:  <class 'list'>
#
# url :  https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us
# Tipo de dato:  <class 'str'>
# None
# ANALISIS PRELIMINAR DATASET: 3.json
#
# EJEMPLOS NO NULOS:
#
# name :  Porter Pharmacy
# Tipo de dato:  <class 'str'>
#
# address :  Porter Pharmacy, 129 N Second St, Cochran, GA 31014
# Tipo de dato:  <class 'str'>
#
# gmap_id :  0x88f16e41928ff687:0x883dad4fd048e8f8
# Tipo de dato:  <class 'str'>
#
# description :  Drugstore chain selling a variety of beauty & health products, plus some grocery & household items.
# Tipo de dato:  <class 'str'>
#
# latitude :  32.3883
# Tipo de dato:  <class 'float'>
#
# longitude :  -83.3571
# Tipo de dato:  <class 'float'>
#
# category :  ['Pharmacy']
# Tipo de dato:  <class 'list'>
#
# avg_rating :  4.9
# Tipo de dato:  <class 'float'>
#
# num_of_reviews :  16
# Tipo de dato:  <class 'int'>
#
# price :  $$
# Tipo de dato:  <class 'str'>
#
# hours :  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM'], ['Sunday', 'Closed'], ['Monday', '8AM–6PM'], ['Tuesday', '8AM–6PM'], ['Wednesday', '8AM–12PM'], ['Thursday', '8AM–6PM']]
# Tipo de dato:  <class 'list'>
#
# MISC :  {'Service options': ['In-store shopping', 'Same-day delivery'], 'Health & safety': ['Mask required', 'Staff required to disinfect surfaces between visits'], 'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Quick visit']}
# Tipo de dato:  <class 'dict'>
#
# state :  Open ⋅ Closes 6PM
# Tipo de dato:  <class 'str'>
#
# relative_results :  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x88f16c32716531c1:0x5f19bdaa5044e4fa', '0x88f16e6e3f4a21df:0xcf495da9bb4d89ea']
# Tipo de dato:  <class 'list'>
#
# url :  https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us
# Tipo de dato:  <class 'str'>
# None
# ANALISIS PRELIMINAR DATASET: 4.json
#
# EJEMPLOS NO NULOS:
#
# name :  Porter Pharmacy
# Tipo de dato:  <class 'str'>
#
# address :  Porter Pharmacy, 129 N Second St, Cochran, GA 31014
# Tipo de dato:  <class 'str'>
#
# gmap_id :  0x88f16e41928ff687:0x883dad4fd048e8f8
# Tipo de dato:  <class 'str'>
#
# description :  Chain retailer specializing in sofas, beds & mattresses, plus home & office furniture.
# Tipo de dato:  <class 'str'>
#
# latitude :  32.3883
# Tipo de dato:  <class 'float'>
#
# longitude :  -83.3571
# Tipo de dato:  <class 'float'>
#
# category :  ['Pharmacy']
# Tipo de dato:  <class 'list'>
#
# avg_rating :  4.9
# Tipo de dato:  <class 'float'>
#
# num_of_reviews :  16
# Tipo de dato:  <class 'int'>
#
# price :  $
# Tipo de dato:  <class 'str'>
#
# hours :  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM'], ['Sunday', 'Closed'], ['Monday', '8AM–6PM'], ['Tuesday', '8AM–6PM'], ['Wednesday', '8AM–12PM'], ['Thursday', '8AM–6PM']]
# Tipo de dato:  <class 'list'>
#
# MISC :  {'Service options': ['In-store shopping', 'Same-day delivery'], 'Health & safety': ['Mask required', 'Staff required to disinfect surfaces between visits'], 'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Quick visit']}
# Tipo de dato:  <class 'dict'>
#
# state :  Open ⋅ Closes 6PM
# Tipo de dato:  <class 'str'>
#
# relative_results :  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x88f16c32716531c1:0x5f19bdaa5044e4fa', '0x88f16e6e3f4a21df:0xcf495da9bb4d89ea']
# Tipo de dato:  <class 'list'>
#
# url :  https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us
# Tipo de dato:  <class 'str'>
# None
# ANALISIS PRELIMINAR DATASET: 5.json
#
# EJEMPLOS NO NULOS:
#
# name :  Porter Pharmacy
# Tipo de dato:  <class 'str'>
#
# address :  Porter Pharmacy, 129 N Second St, Cochran, GA 31014
# Tipo de dato:  <class 'str'>
#
# gmap_id :  0x88f16e41928ff687:0x883dad4fd048e8f8
# Tipo de dato:  <class 'str'>
#
# description :  Chain with a wide variety of agricultural & livestock supplies, plus tools, workwear & boots.
# Tipo de dato:  <class 'str'>
#
# latitude :  32.3883
# Tipo de dato:  <class 'float'>
#
# longitude :  -83.3571
# Tipo de dato:  <class 'float'>
#
# category :  ['Pharmacy']
# Tipo de dato:  <class 'list'>
#
# avg_rating :  4.9
# Tipo de dato:  <class 'float'>
#
# num_of_reviews :  16
# Tipo de dato:  <class 'int'>
#
# price :  $$
# Tipo de dato:  <class 'str'>
#
# hours :  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM'], ['Sunday', 'Closed'], ['Monday', '8AM–6PM'], ['Tuesday', '8AM–6PM'], ['Wednesday', '8AM–12PM'], ['Thursday', '8AM–6PM']]
# Tipo de dato:  <class 'list'>
#
# MISC :  {'Service options': ['In-store shopping', 'Same-day delivery'], 'Health & safety': ['Mask required', 'Staff required to disinfect surfaces between visits'], 'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Quick visit']}
# Tipo de dato:  <class 'dict'>
#
# state :  Open ⋅ Closes 6PM
# Tipo de dato:  <class 'str'>
#
# relative_results :  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x88f16c32716531c1:0x5f19bdaa5044e4fa', '0x88f16e6e3f4a21df:0xcf495da9bb4d89ea']
# Tipo de dato:  <class 'list'>
#
# url :  https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us
# Tipo de dato:  <class 'str'>
# None
# ANALISIS PRELIMINAR DATASET: 6.json
#
# EJEMPLOS NO NULOS:
#
# name :  Porter Pharmacy
# Tipo de dato:  <class 'str'>
#
# address :  Porter Pharmacy, 129 N Second St, Cochran, GA 31014
# Tipo de dato:  <class 'str'>
#
# gmap_id :  0x88f16e41928ff687:0x883dad4fd048e8f8
# Tipo de dato:  <class 'str'>
#
# description :  Chain retailer selling a wide array of branded spring, memory foam & adjustable mattresses.
# Tipo de dato:  <class 'str'>
#
# latitude :  32.3883
# Tipo de dato:  <class 'float'>
#
# longitude :  -83.3571
# Tipo de dato:  <class 'float'>
#
# category :  ['Pharmacy']
# Tipo de dato:  <class 'list'>
#
# avg_rating :  4.9
# Tipo de dato:  <class 'float'>
#
# num_of_reviews :  16
# Tipo de dato:  <class 'int'>
#
# price :  $
# Tipo de dato:  <class 'str'>
#
# hours :  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM'], ['Sunday', 'Closed'], ['Monday', '8AM–6PM'], ['Tuesday', '8AM–6PM'], ['Wednesday', '8AM–12PM'], ['Thursday', '8AM–6PM']]
# Tipo de dato:  <class 'list'>
#
# MISC :  {'Service options': ['In-store shopping', 'Same-day delivery'], 'Health & safety': ['Mask required', 'Staff required to disinfect surfaces between visits'], 'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Quick visit']}
# Tipo de dato:  <class 'dict'>
#
# state :  Open ⋅ Closes 6PM
# Tipo de dato:  <class 'str'>
#
# relative_results :  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x88f16c32716531c1:0x5f19bdaa5044e4fa', '0x88f16e6e3f4a21df:0xcf495da9bb4d89ea']
# Tipo de dato:  <class 'list'>
#
# url :  https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us
# Tipo de dato:  <class 'str'>
# None
# ANALISIS PRELIMINAR DATASET: 7.json
#
# EJEMPLOS NO NULOS:
#
# name :  Porter Pharmacy
# Tipo de dato:  <class 'str'>
#
# address :  Porter Pharmacy, 129 N Second St, Cochran, GA 31014
# Tipo de dato:  <class 'str'>
#
# gmap_id :  0x88f16e41928ff687:0x883dad4fd048e8f8
# Tipo de dato:  <class 'str'>
#
# description :  Floral design shop for all-occasion bouquets, cut stems, grab-&-go arrangements & gifts.
# Tipo de dato:  <class 'str'>
#
# latitude :  32.3883
# Tipo de dato:  <class 'float'>
#
# longitude :  -83.3571
# Tipo de dato:  <class 'float'>
#
# category :  ['Pharmacy']
# Tipo de dato:  <class 'list'>
#
# avg_rating :  4.9
# Tipo de dato:  <class 'float'>
#
# num_of_reviews :  16
# Tipo de dato:  <class 'int'>
#
# price :  $
# Tipo de dato:  <class 'str'>
#
# hours :  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM'], ['Sunday', 'Closed'], ['Monday', '8AM–6PM'], ['Tuesday', '8AM–6PM'], ['Wednesday', '8AM–12PM'], ['Thursday', '8AM–6PM']]
# Tipo de dato:  <class 'list'>
#
# MISC :  {'Service options': ['In-store shopping', 'Same-day delivery'], 'Health & safety': ['Mask required', 'Staff required to disinfect surfaces between visits'], 'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Quick visit']}
# Tipo de dato:  <class 'dict'>
#
# state :  Open ⋅ Closes 6PM
# Tipo de dato:  <class 'str'>
#
# relative_results :  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x88f16c32716531c1:0x5f19bdaa5044e4fa', '0x88f16e6e3f4a21df:0xcf495da9bb4d89ea']
# Tipo de dato:  <class 'list'>
#
# url :  https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us
# Tipo de dato:  <class 'str'>
# None
# ANALISIS PRELIMINAR DATASET: 8.json
#
# EJEMPLOS NO NULOS:
#
# name :  Porter Pharmacy
# Tipo de dato:  <class 'str'>
#
# address :  Porter Pharmacy, 129 N Second St, Cochran, GA 31014
# Tipo de dato:  <class 'str'>
#
# gmap_id :  0x88f16e41928ff687:0x883dad4fd048e8f8
# Tipo de dato:  <class 'str'>
#
# description :  Discount retailer of cigarettes, cigars & other tobacco products & accessories, including humidors.
# Tipo de dato:  <class 'str'>
#
# latitude :  32.3883
# Tipo de dato:  <class 'float'>
#
# longitude :  -83.3571
# Tipo de dato:  <class 'float'>
#
# category :  ['Pharmacy']
# Tipo de dato:  <class 'list'>
#
# avg_rating :  4.9
# Tipo de dato:  <class 'float'>
#
# num_of_reviews :  16
# Tipo de dato:  <class 'int'>
#
# price :  $$
# Tipo de dato:  <class 'str'>
#
# hours :  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM'], ['Sunday', 'Closed'], ['Monday', '8AM–6PM'], ['Tuesday', '8AM–6PM'], ['Wednesday', '8AM–12PM'], ['Thursday', '8AM–6PM']]
# Tipo de dato:  <class 'list'>
#
# MISC :  {'Service options': ['In-store shopping', 'Same-day delivery'], 'Health & safety': ['Mask required', 'Staff required to disinfect surfaces between visits'], 'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Quick visit']}
# Tipo de dato:  <class 'dict'>
#
# state :  Open ⋅ Closes 6PM
# Tipo de dato:  <class 'str'>
#
# relative_results :  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x88f16c32716531c1:0x5f19bdaa5044e4fa', '0x88f16e6e3f4a21df:0xcf495da9bb4d89ea']
# Tipo de dato:  <class 'list'>
#
# url :  https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us
# Tipo de dato:  <class 'str'>
# None
# ANALISIS PRELIMINAR DATASET: 9.json
#
# EJEMPLOS NO NULOS:
#
# name :  Porter Pharmacy
# Tipo de dato:  <class 'str'>
#
# address :  Porter Pharmacy, 129 N Second St, Cochran, GA 31014
# Tipo de dato:  <class 'str'>
#
# gmap_id :  0x88f16e41928ff687:0x883dad4fd048e8f8
# Tipo de dato:  <class 'str'>
#
# description :  Family-friendly chain known for its made-to-order pizzas.
# Tipo de dato:  <class 'str'>
#
# latitude :  32.3883
# Tipo de dato:  <class 'float'>
#
# longitude :  -83.3571
# Tipo de dato:  <class 'float'>
#
# category :  ['Pharmacy']
# Tipo de dato:  <class 'list'>
#
# avg_rating :  4.9
# Tipo de dato:  <class 'float'>
#
# num_of_reviews :  16
# Tipo de dato:  <class 'int'>
#
# price :  $
# Tipo de dato:  <class 'str'>
#
# hours :  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM'], ['Sunday', 'Closed'], ['Monday', '8AM–6PM'], ['Tuesday', '8AM–6PM'], ['Wednesday', '8AM–12PM'], ['Thursday', '8AM–6PM']]
# Tipo de dato:  <class 'list'>
#
# MISC :  {'Service options': ['In-store shopping', 'Same-day delivery'], 'Health & safety': ['Mask required', 'Staff required to disinfect surfaces between visits'], 'Accessibility': ['Wheelchair accessible entrance'], 'Planning': ['Quick visit']}
# Tipo de dato:  <class 'dict'>
#
# state :  Open ⋅ Closes 6PM
# Tipo de dato:  <class 'str'>
#
# relative_results :  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x88f16c32716531c1:0x5f19bdaa5044e4fa', '0x88f16e6e3f4a21df:0xcf495da9bb4d89ea']
# Tipo de dato:  <class 'list'>
#
# url :  https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us
# Tipo de dato:  <class 'str'>
# None

# %%
idem_titulos = 'Las columnas son equivalentes' #Variable simil a un flag indicando que en todos los df las columnas son identicas en nombres y cantidad
idem_tipos = 'Los tipos de datos son equivalentes' #Idem anterior
#Se itera la lista titulos, se da por hecho que la lista tipos tiene la misma longitud ya que surgen de la iteracion de dataframes
for i in range(1, len(titulos)):#Iteracion arrancando por el segundo elemento de la lista, se comparara con el elemento anterior
    if titulos[i] != titulos[i - 1]:
        idem_titulos = 'Hay diferencias' #Si encuentra diferencia cambia el flag de titulos

    if tipos[i] != tipos[i - 1]:
        idem_tipos = 'Hay diferencias' #Si encuentra diferencia cambia el flag de tipos

print('Titulos: ', idem_titulos)
print()
print('Tipos de datos: ', idem_tipos)
# Out:
# Titulos:  Las columnas son equivalentes
#
# Tipos de datos:  Los tipos de datos son equivalentes

# %%
df_final = pd.concat(lista_df, ignore_index=True)#Concatenacion de todos los df
df_final.to_parquet('metadata_google.parquet')#Cargar en un archivo .parquet

# %%
df_uni = pd.read_parquet('metadata_google.parquet', engine='fastparquet')

# %%
df_uni.head(3)
# Out:
#               name                                            address  \
# 0  Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1     City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2     San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
#
#                                  gmap_id description   latitude  longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.35710
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.21529
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.29213
#
#               category  avg_rating  num_of_reviews price  ...  \
# 0           [Pharmacy]         4.9              16  None  ...
# 1   [Textile exporter]         4.5               6  None  ...
# 2  [Korean restaurant]         4.4              18  None  ...
#
#                                 MISC.Health & safety MISC.Health and safety  \
# 0  [Mask required, Staff required to disinfect su...                     []
# 1                                               None                   None
# 2                                                 []                     []
#
#   MISC.Highlights MISC.Lodging options  MISC.Offerings MISC.Payments  \
# 0              []                   []              []            []
# 1            None                 None            None          None
# 2              []                   []  [Comfort food]            []
#
#    MISC.Planning MISC.Popular for MISC.Recycling  \
# 0  [Quick visit]               []             []
# 1           None             None           None
# 2             []               []             []
#
#                      MISC.Service options
# 0  [In-store shopping, Same-day delivery]
# 1                                    None
# 2            [Takeout, Dine-in, Delivery]
#
# [3 rows x 32 columns]

# %%
df_uni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3025011 entries, 0 to 3025010
# Data columns (total 32 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   name                    object
#  1   address                 object
#  2   gmap_id                 object
#  3   description             object
#  4   latitude                float64
#  5   longitude               float64
#  6   category                object
#  7   avg_rating              float64
#  8   num_of_reviews          int64
#  9   price                   object
#  10  hours                   object
#  11  state                   object
#  12  relative_results        object
#  13  url                     object
#  14  MISC.Accessibility      object
#  15  MISC.Activities         object
#  16  MISC.Amenities          object
#  17  MISC.Atmosphere         object
#  18  MISC.Crowd              object
#  19  MISC.Dining options     object
#  20  MISC.From the business  object
#  21  MISC.Getting here       object
#  22  MISC.Health & safety    object
#  23  MISC.Health and safety  object
#  24  MISC.Highlights         object
#  25  MISC.Lodging options    object
#  26  MISC.Offerings          object
#  27  MISC.Payments           object
#  28  MISC.Planning           object
#  29  MISC.Popular for        object
#  30  MISC.Recycling          object
#  31  MISC.Service options    object
# dtypes: float64(3), int64(1), object(28)
# memory usage: 738.5+ MB

# %%
imprimir_ejemplos(df_uni)
# Out:
# name :  Porter Pharmacy
# Tipo de dato:  <class 'str'>
#
# address :  Porter Pharmacy, 129 N Second St, Cochran, GA 31014
# Tipo de dato:  <class 'str'>
#
# gmap_id :  0x88f16e41928ff687:0x883dad4fd048e8f8
# Tipo de dato:  <class 'str'>
#
# description :  Chain selling interior & exterior paints, primers & finishes, plus supplies.
# Tipo de dato:  <class 'str'>
#
# latitude :  32.3883
# Tipo de dato:  <class 'float'>
#
# longitude :  -83.3571
# Tipo de dato:  <class 'float'>
#
# category :  ['Pharmacy']
# Tipo de dato:  <class 'list'>
#
# avg_rating :  4.9
# Tipo de dato:  <class 'float'>
#
# num_of_reviews :  16
# Tipo de dato:  <class 'int'>
#
# price :  $
# Tipo de dato:  <class 'str'>
#
# state :  Open ⋅ Closes 6PM
# Tipo de dato:  <class 'str'>
#
# relative_results :  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x88f16c32716531c1:0x5f19bdaa5044e4fa', '0x88f16e6e3f4a21df:0xcf495da9bb4d89ea']
# Tipo de dato:  <class 'list'>
#
# url :  https://www.google.com/maps/place//data=!4m2!3m1!1s0x88f16e41928ff687:0x883dad4fd048e8f8?authuser=-1&hl=en&gl=us
# Tipo de dato:  <class 'str'>
#
# MISC.Accessibility :  ['Wheelchair accessible entrance']
# Tipo de dato:  <class 'list'>
#
# MISC.Activities :  []
# Tipo de dato:  <class 'list'>
#
# MISC.Amenities :  []
# Tipo de dato:  <class 'list'>
#
# MISC.Atmosphere :  []
# Tipo de dato:  <class 'list'>
#
# MISC.Crowd :  []
# Tipo de dato:  <class 'list'>
#
# MISC.Dining options :  []
# Tipo de dato:  <class 'list'>
#
# MISC.From the business :  []
# Tipo de dato:  <class 'list'>
#
# MISC.Getting here :  []
# Tipo de dato:  <class 'list'>
#
# MISC.Health & safety :  ['Mask required', 'Staff required to disinfect surfaces between visits']
# Tipo de dato:  <class 'list'>
#
# MISC.Health and safety :  []
# Tipo de dato:  <class 'list'>
#
# MISC.Highlights :  []
# Tipo de dato:  <class 'list'>
#
# MISC.Lodging options :  []
# Tipo de dato:  <class 'list'>
#
# MISC.Offerings :  []
# Tipo de dato:  <class 'list'>
#
# MISC.Payments :  []
# Tipo de dato:  <class 'list'>
#
# MISC.Planning :  ['Quick visit']
# Tipo de dato:  <class 'list'>
#
# MISC.Popular for :  []
# Tipo de dato:  <class 'list'>
#
# MISC.Recycling :  []
# Tipo de dato:  <class 'list'>
#
# MISC.Service options :  ['In-store shopping', 'Same-day delivery']
# Tipo de dato:  <class 'list'>

# %%
df_uni.name.value_counts()
# Out:
# name
# Subway                                                                         9140
# United States Postal Service                                                   7388
# Shell                                                                          6615
# U-Haul Neighborhood Dealer                                                     4972
# Walgreens                                                                      4690
#                                                                                ...
# GAR Properties                                                                    1
# Interstate Real Estate Services Inc                                               1
# Gile Blueberry Farm                                                               1
# The Dunn Team (Conor Dunn, Mark Dunn & Natalia Marin Santa) Coldwell Banker       1
# Arizona LINE-X                                                                    1
# Name: count, Length: 2308005, dtype: int64

# %% [markdown]
# name: Este campo contiene los nombres comerciales de los establecimientos, al encontrarse nombres repetidos se puede presuponer que se hallan varias sucursales del mismo comercio, siendo los que poseen mayor cantidad de sucursales: Subway con 9140, United States Postal Service con 7388 y Shell con 6615.

# %%
df_uni.address.value_counts()
# Out:
# address
# Porter Pharmacy, 129 N Second St, Cochran, GA 31014                               12
# Florida                                                                           12
# Van Zandt County, TX 75754                                                         9
# Coleman County, TX 76878                                                           7
# Van Zandt County, TX 75103                                                         6
#                                                                                   ..
# Lake Livingston Water Supply Corp, 1930 N Washington Ave, Livingston, TX 77351     1
# Westco Donut, 1304 N Washington Ave, Livingston, TX 77351                          1
# Orlando Garcia, Attorney at Law, 507 E Hospital St #105, Nacogdoches, TX 75961     1
# AP Law, 501 N Magnolia Ave Suite A4, Orlando, FL 32801                             1
# US Forest Services Ranger Station, 333 E Main St, Lander, WY 82520                 1
# Name: count, Length: 2915755, dtype: int64

# %% [markdown]
# address: Hay direcciones repetidas, esto puede tratarse de filas repetidas, establecimientos inexistentes en cuya direccion se registro otra firma o simplemente edificios multicomerciales en con cuales en el mismo domicilio hay varios establecimientos.

# %%
df_uni.gmap_id.value_counts()
# Out:
# gmap_id
# 0x88f16e41928ff687:0x883dad4fd048e8f8    12
# 0x89e3a441030d3ea3:0xf4298fc100359795     2
# 0x89b903ea489d91c5:0xb6015f2f3040bc16     2
# 0x89b9039d9b637f51:0xa0af5e1ba8476be6     2
# 0x89b92691537e0897:0xb91916d9fc34a220     2
#                                          ..
# 0x883b4d9e00a8b94b:0x9817344cf61bf2df     1
# 0x88234ac651cd16cf:0xd489597c33bbee12     1
# 0x883b5378570355f1:0xa8db1a57fa275fb7     1
# 0x878e07fa5e993ea5:0xc5e51123d1f83e9b     1
# 0x875901f1fbd58357:0xed5174d5b088430c     1
# Name: count, Length: 2998428, dtype: int64

# %% [markdown]
# gmap_id: Se debe analizar si el hecho de encontrarse identificadores repetidos se debe a filas repetidas o el hecho de que el identificador no sea unico. No coincide la cantidad de identificadores con la cantidad de direcciones.

# %%
df_uni.description.value_counts()
# Out:
# description
# Casual counter-serve chain for build-your-own sandwiches & salads, with health-conscious options.      9773
# Convenience chain offering grab-&-go bites & beverages, plus assorted newsstand items.                 4762
# Drugstore chain with health & beauty aids, prescriptions & photo services, plus mini-mart basics.      4656
# Drugstore chain selling a variety of beauty & health products, plus some grocery & household items.    4584
# Kiosk chain renting movies, including new releases (many are located inside stores).                   4564
#                                                                                                        ...
# Longtime gallery established in 1950 showcasing rotating exhibits of modern & contemporary art.           1
# Grouping of fenced geothermal pools in rural surrounds, a known stop on the California Trail.             1
# Popular eatery whipping up lunch-oriented Japanese grub in utilitarian digs with outdoor seating.         1
# Spacious sports bar offering an eclectic American menu & a 23-tap bar amid brick walls & large TVs.       1
# Innovative, globally inspired dishes are paired with wine, cocktails & sake in offbeat surrounds.         1
# Name: count, Length: 70925, dtype: int64

# %% [markdown]
# description: Se observa superioridad en cantidad de cadenas de sandwicherias.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_uni.longitude, df_uni.latitude, color='red', alpha=0.5)
plt.title('Dispersion de ubicaciones')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.tight_layout
plt.show()

# %% [markdown]
# Se puede deducir que si bien la mayor concentracion de datos se encuentra en proximidades a EEUU Latitud 41 - Longitud -96 aproximadamente, se puede observar outliers con valores de otras partes del mundo, puede deberse a datos erroneos en las direcciones.

# %%
df_uni.avg_rating.describe()
# Out:
# count    3.025011e+06
# mean     4.303736e+00
# std      7.127077e-01
# min      1.000000e+00
# 25%      4.000000e+00
# 50%      4.500000e+00
# 75%      4.800000e+00
# max      5.000000e+00
# Name: avg_rating, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(df_uni.avg_rating, fill=True)
plt.title('Calificacion de establecimientos')
plt.xlabel('Puntaje')
plt.ylabel('Frecuencia')
plt.yticks([])
plt.tight_layout
plt.show()

# %% [markdown]
# avg_rating: Es la calificacion que reciben los establecimientos en una escala de 1 a 5. Se observa que el 75% de las entradas de todo el dataset tienen calificaciones de 4 puntos o mas.

# %%
df_uni.num_of_reviews.mean()
# Out:
# 43.629109778443784

# %%
plt.figure(figsize=(10, 6))
plt.hist(df_uni.num_of_reviews, bins=100, color='blue')
plt.title('Cantidad de reviews')
plt.xlabel('Cantidad')
plt.ylabel('Frecuencia')
plt.ticklabel_format(axis='y', style='plain')
plt.tight_layout
plt.show()

# %% [markdown]
# Se observa gran cantidad de establecimientos con cantidades bajas de reviews, puede estar directamente relacionado con el tamaño del comercio.

# %%
df_uni.price.unique()
# Out:
# array([None, '$', '$$', '$$$', '$$$$', '₩', '₩₩', '₩₩₩', '₩₩₩₩'],
#       dtype=object)

# %% [markdown]
# price: No hay datos respecto a los precios.

# %%
df_uni.state.value_counts()
# Out:
# state
# Permanently closed                          190813
# Open 24 hours                               156263
# Closed ⋅ Opens 9AM                          137485
# Closed ⋅ Opens 8AM                          123238
# Open ⋅ Closes 5PM                           115301
#                                              ...
# Closes soon ⋅ 3:30PM ⋅ Opens 11:30AM Tue         1
# Closes soon ⋅ 9:30AM ⋅ Opens 8:30AM Tue          1
# Closes soon ⋅ 10AM ⋅ Opens 6AM Fri               1
# Closed ⋅ Opens 10:22AM Mon                       1
# Closes soon ⋅ 2:30PM ⋅ Opens 6AM Sun             1
# Name: count, Length: 6291, dtype: int64

# %% [markdown]
# Prevalecen los establecimientos que se encuentran permanentemente cerrados (se presupone que estos comercios que son 190813 ya no existen), y en segundo lugar los establecimientos abiertos 24 horas. Teniendo en cuenta las siguientes categorias se puede deducir que buena parte de los establecimientos abren sus puertas entre 8 y 9 AM y las cierran a las 5 PM.

# %%
lista_categorias = []
def extraer_category(dato):
    if type(dato) == list:
        for elemento in dato:
            lista_categorias.append(elemento)
    
    return dato

df_uni['category'].apply(extraer_category)

print(len(lista_categorias))
# Out:
# 6262696

# %%
categorias = Counter(lista_categorias)
wordcloud = WordCloud(width=1000, height=600, background_color='white').generate_from_frequencies(categorias)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# Se grafico una nube de palabras basado en la frecuencia de repeticiones de las diferentes categorias, arrojando visualmente el grafico que la categoria Restaurant es la que clasifica mayor numero de establecimiento entre las mismas.
# Campo analizado: category

# %%
top_tres = categorias.most_common(3)
print(f'Total de establecimientos con categoria {top_tres[0][0]}: {top_tres[0][1]}')
print(f'Total de establecimientos con categoria {top_tres[1][0]}: {top_tres[1][1]}')
print(f'Total de establecimientos con categoria {top_tres[2][0]}: {top_tres[2][1]}')
# Out:
# Total de establecimientos con categoria Restaurant: 97257
# Total de establecimientos con categoria Auto repair shop: 77854
# Total de establecimientos con categoria Gas station: 70143

# %% [markdown]
# category: Se puede observar que existen 97257 establecimientos encuadrados en la categoria Restaurant, 77854 en la categoria Auto Repair Shop y $70143 en la categoria Gas Station, siendo Restaurant la categoria de la cual existe mayor cantidad de establecimientos.

# %%
df_uni.price.unique()
# Out:
# array([None, '$', '$$', '$$$', '$$$$', '₩', '₩₩', '₩₩₩', '₩₩₩₩'],
#       dtype=object)

# %%
df_uni.name.unique()
# Out:
# array(['Porter Pharmacy', 'City Textile', 'San Soo Dang', ...,
#        'The Green Room Of Libertyville', 'Klein Brothers Packaging',
#        'Arizona LINE-X'], dtype=object)

# %%
df_uni.address.unique()
# Out:
# array(['Porter Pharmacy, 129 N Second St, Cochran, GA 31014',
#        'City Textile, 3001 E Pico Blvd, Los Angeles, CA 90023',
#        'San Soo Dang, 761 S Vermont Ave, Los Angeles, CA 90005', ...,
#        'Profiles Hair Design, 522 N Federal Blvd, Riverton, WY 82501',
#        'Arizona LINE-X, 21242 N Black Canyon Hwy #A, Phoenix, AZ 85027',
#        'US Forest Services Ranger Station, 333 E Main St, Lander, WY 82520'],
#       dtype=object)

# %%
len(df_uni.gmap_id.unique())
# Out:
# 2998428

# %%
df_uni.gmap_id.value_counts()
# Out:
# gmap_id
# 0x88f16e41928ff687:0x883dad4fd048e8f8    12
# 0x89e3a441030d3ea3:0xf4298fc100359795     2
# 0x89b903ea489d91c5:0xb6015f2f3040bc16     2
# 0x89b9039d9b637f51:0xa0af5e1ba8476be6     2
# 0x89b92691537e0897:0xb91916d9fc34a220     2
#                                          ..
# 0x883b4d9e00a8b94b:0x9817344cf61bf2df     1
# 0x88234ac651cd16cf:0xd489597c33bbee12     1
# 0x883b5378570355f1:0xa8db1a57fa275fb7     1
# 0x878e07fa5e993ea5:0xc5e51123d1f83e9b     1
# 0x875901f1fbd58357:0xed5174d5b088430c     1
# Name: count, Length: 2998428, dtype: int64

# %%
df_uni[df_uni['gmap_id'] == '0x89e3a441030d3ea3:0xf4298fc100359795']
# Out:
#             name                                      address  \
# 17712  Girls Inc  Girls Inc, 220 Worthen St, Lowell, MA 01852
# 44285  Girls Inc  Girls Inc, 220 Worthen St, Lowell, MA 01852
#
#                                      gmap_id description   latitude  \
# 17712  0x89e3a441030d3ea3:0xf4298fc100359795        None  42.644773
# 44285  0x89e3a441030d3ea3:0xf4298fc100359795        None  42.644773
#
#        longitude                   category  avg_rating  num_of_reviews price  \
# 17712 -71.314618  [Non-profit organization]         4.4              16  None
# 44285 -71.314618  [Non-profit organization]         4.4              16  None
#
#        ... MISC.Health & safety MISC.Health and safety MISC.Highlights  \
# 17712  ...                   []                     []              []
# 44285  ...                   []                     []              []
#
#       MISC.Lodging options MISC.Offerings MISC.Payments MISC.Planning  \
# 17712                   []             []            []            []
# 44285                   []             []            []            []
#
#       MISC.Popular for MISC.Recycling MISC.Service options
# 17712               []             []                   []
# 44285               []             []                   []
#
# [2 rows x 32 columns]

# %%
df_uni.hours.unique()
# Out:
# array([None], dtype=object)

# %%
df_uni.state.unique()
# Out:
# array(['Open ⋅ Closes 6PM', 'Open now', 'Open ⋅ Closes 5PM', ...,
#        'Closes soon ⋅ 3PM ⋅ Opens 12:30PM Sun',
#        'Closes soon ⋅ 2PM ⋅ Opens 6AM Sun',
#        'Closes soon ⋅ 2:30PM ⋅ Opens 6AM Sun'], dtype=object)

# %%
df_uni.relative_results
# Out:
# 0          [0x88f16e41929435cf:0x5b2532a2885e9ef6, 0x88f1...
# 1          [0x80c2c624136ea88b:0xb0315367ed448771, 0x80c2...
# 2          [0x80c2c78249aba68f:0x35bf16ce61be751d, 0x80c2...
# 3          [0x80c2c8811477253f:0x23a8a492df1918f7, 0x80c2...
# 4          [0x80c2c62c496083d1:0xdefa11317fe870a1, 0x80c2...
#                                  ...
# 3025006    [0x880f96c848329bd5:0x5a6609c274091c81, 0x880f...
# 3025007    [0x80900c2bd9b41a37:0x5de883f3a0746a61, 0x8090...
# 3025008    [0x8758dd1ffba87d8f:0xf211a1ebf7297000, 0x8758...
# 3025009    [0x872b6f9d1b41ad95:0x94a335fc923f0987, 0x872b...
# 3025010    [0x8758fe025f4f7419:0xc98c1e92db448cb8, 0x8759...
# Name: relative_results, Length: 3025011, dtype: object

# %%
df_uni['MISC.Dining options'].value_counts()
# Out:
# MISC.Dining options
# []                                                                  2185908
# [Dessert]                                                             48043
# [Lunch, Dinner]                                                       11472
# [Lunch, Dinner, Catering, Dessert, Seating]                            7584
# [Lunch, Dinner, Dessert]                                               5599
#                                                                      ...
# [Catering, Dessert, Pay ahead, Seating]                                   1
# [Breakfast, Lunch, Dinner, Dessert, Pay ahead, Seating]                   1
# [Breakfast, Dessert, Outside food allowed, Seating]                       1
# [Dinner, Catering, Counter service]                                       1
# [Breakfast, Dinner, Catering, Counter service, Dessert, Seating]          1
# Name: count, Length: 168, dtype: int64

# %%
df_uni['MISC.Accessibility'].value_counts()
# Out:
# MISC.Accessibility
# [Wheelchair accessible entrance]                                                                                                                    1620618
# []                                                                                                                                                   385591
# [Wheelchair accessible entrance, Wheelchair accessible parking lot]                                                                                  124046
# [Wheelchair accessible entrance, Wheelchair accessible restroom]                                                                                      55758
# [Wheelchair accessible entrance, Wheelchair accessible parking lot, Wheelchair accessible restroom]                                                   23282
#                                                                                                                                                      ...
# [Assisted listening devices]                                                                                                                              1
# [Assistive hearing loop, Wheelchair accessible entrance, Wheelchair accessible restroom, Wheelchair accessible seating]                                   1
# [Wheelchair-accessible car park, Wheelchair-accessible entrance, Wheelchair-accessible seating, Wheelchair-accessible toilet, Wheelchair rental]          1
# [Wheelchair-accessible lift, Wheelchair-accessible seating, Wheelchair-accessible toilet]                                                                 1
# [Assisted listening devices, Wheelchair accessible entrance, Wheelchair accessible seating]                                                               1
# Name: count, Length: 192, dtype: int64

# %%
categorias_unicas = set(lista_categorias)
len(categorias_unicas)
# Out:
# 4471

# %%
df_otro = df_uni.copy()

# %%
df_otro['category'] = df_otro['category'].astype(str)

# %%
reducido = df_otro[df_otro['category'].str.contains('restaurant|food|cafe|delivery|bar|pizza|sandwich', case=False)]
reducido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 326132 entries, 2 to 3025006
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   name                    326132 non-null  object
#  1   address                 323665 non-null  object
#  2   gmap_id                 326132 non-null  object
#  3   description             88429 non-null   object
#  4   latitude                326132 non-null  float64
#  5   longitude               326132 non-null  float64
#  6   category                326132 non-null  object
#  7   avg_rating              326132 non-null  float64
#  8   num_of_reviews          326132 non-null  int64
#  9   price                   126848 non-null  object
#  10  hours                   0 non-null       object
#  11  state                   291077 non-null  object
#  12  relative_results        272854 non-null  object
#  13  url                     326132 non-null  object
#  14  MISC.Accessibility      312143 non-null  object
#  15  MISC.Activities         312143 non-null  object
#  16  MISC.Amenities          312143 non-null  object
#  17  MISC.Atmosphere         312143 non-null  object
#  18  MISC.Crowd              312143 non-null  object
#  19  MISC.Dining options     312143 non-null  object
#  20  MISC.From the business  312143 non-null  object
#  21  MISC.Getting here       312143 non-null  object
#  22  MISC.Health & safety    312143 non-null  object
#  23  MISC.Health and safety  312143 non-null  object
#  24  MISC.Highlights         312143 non-null  object
#  25  MISC.Lodging options    312143 non-null  object
#  26  MISC.Offerings          312143 non-null  object
#  27  MISC.Payments           312143 non-null  object
#  28  MISC.Planning           312143 non-null  object
#  29  MISC.Popular for        312143 non-null  object
#  30  MISC.Recycling          312143 non-null  object
#  31  MISC.Service options    312143 non-null  object
# dtypes: float64(3), int64(1), object(28)
# memory usage: 82.1+ MB

# %%
#El componente nombre del string contiene comas entreveradas
address = reducido['address'].str[::-1].str.rsplit(',', expand=True)#Se invierte el string y se splitea
address = address.iloc[:, :3]#Se seleccionan las primeras 3 columnas
address = address.apply(lambda x: x.str[::-1])#Se invierte el string en cada columna
address.columns = ['postal_code', 'city', 'number_and_street']#Se nombran las columnas
address.head()
# Out:
#    postal_code          city      number_and_street
# 2     CA 90005   Los Angeles      761 S Vermont Ave
# 6     CA 90638     La Mirada   12740 La Mirada Blvd
# 8     IA 50263        Waukee      85 NE Dartmoor Dr
# 36    TX 75041       Garland       3838 W Miller Rd
# 57    PA 18042        Easton     148 W St Joseph St

# %%
reducido = pd.concat([reducido, address], axis=1)#Conctenar
reducido = reducido.drop('address', axis=1)#Eliminar columna address
reducido.head()
# Out:
#                                      name  \
# 2                            San Soo Dang
# 6                            Vons Chicken
# 8   Sweet Rewards Gluten Free Bakery, LLC
# 36                     Luminous Logistics
# 57                     Primo Pizza & Subs
#
#                                   gmap_id description   latitude   longitude  \
# 2   0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 6   0x80dd2b4c8555edb7:0xfc33d65c4bdbef42        None  33.916402 -118.010855
# 8    0x87ec235c54d25b31:0x3b75fb5facc602f        None  41.616079  -93.865487
# 36  0x864ea0993bffffff:0xb50b5bb2fccf9d9b        None  32.893678  -96.688611
# 57  0x89c46d5e4554eae1:0xa2f8b211524ca29a        None  40.682177  -75.209820
#
#                                 category  avg_rating  num_of_reviews price  \
# 2                  ['Korean restaurant']         4.4              18  None
# 6                         ['Restaurant']         4.5              18  None
# 8   ['Bakery', 'Health food restaurant']         4.7              21  None
# 36                  ['Delivery service']         2.3               8  None
# 57                    ['Pizza delivery']         4.5              25    $$
#
#    hours  ... MISC.Lodging options                            MISC.Offerings  \
# 2   None  ...                   []                            [Comfort food]
# 6   None  ...                   []  [Comfort food, Quick bite, Small plates]
# 8   None  ...                   []                                        []
# 36  None  ...                 None                                      None
# 57  None  ...                   []                                        []
#
#    MISC.Payments MISC.Planning              MISC.Popular for MISC.Recycling  \
# 2             []            []                            []             []
# 6             []            []  [Lunch, Dinner, Solo dining]             []
# 8             []            []                            []             []
# 36          None          None                          None           None
# 57            []            []                            []             []
#
#                                  MISC.Service options postal_code  \
# 2                        [Takeout, Dine-in, Delivery]    CA 90005
# 6   [Outdoor seating, Curbside pickup, No-contact ...    CA 90638
# 8                                          [Delivery]    IA 50263
# 36                                               None    TX 75041
# 57           [No-contact delivery, Delivery, Takeout]    PA 18042
#
#             city      number_and_street
# 2    Los Angeles      761 S Vermont Ave
# 6      La Mirada   12740 La Mirada Blvd
# 8         Waukee      85 NE Dartmoor Dr
# 36       Garland       3838 W Miller Rd
# 57        Easton     148 W St Joseph St
#
# [5 rows x 34 columns]

# %%
reducido = reducido.drop(['price', 'state', 'hours'], axis=1)
reducido.head()
# Out:
#                                      name  \
# 2                            San Soo Dang
# 6                            Vons Chicken
# 8   Sweet Rewards Gluten Free Bakery, LLC
# 36                     Luminous Logistics
# 57                     Primo Pizza & Subs
#
#                                   gmap_id description   latitude   longitude  \
# 2   0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 6   0x80dd2b4c8555edb7:0xfc33d65c4bdbef42        None  33.916402 -118.010855
# 8    0x87ec235c54d25b31:0x3b75fb5facc602f        None  41.616079  -93.865487
# 36  0x864ea0993bffffff:0xb50b5bb2fccf9d9b        None  32.893678  -96.688611
# 57  0x89c46d5e4554eae1:0xa2f8b211524ca29a        None  40.682177  -75.209820
#
#                                 category  avg_rating  num_of_reviews  \
# 2                  ['Korean restaurant']         4.4              18
# 6                         ['Restaurant']         4.5              18
# 8   ['Bakery', 'Health food restaurant']         4.7              21
# 36                  ['Delivery service']         2.3               8
# 57                    ['Pizza delivery']         4.5              25
#
#                                      relative_results  \
# 2   [0x80c2c78249aba68f:0x35bf16ce61be751d, 0x80c2...
# 6                                                None
# 8   [0x87ee974869295555:0x95f310d065882c9b, 0x87ec...
# 36  [0x864ea09938bb619f:0x1b6902de2a2f3f96, 0x864e...
# 57  [0x89c46c56cac9c661:0xdc9d0dd3f2b203ae, 0x89c4...
#
#                                                   url  ...  \
# 2   https://www.google.com/maps/place//data=!4m2!3...  ...
# 6   https://www.google.com/maps/place//data=!4m2!3...  ...
# 8   https://www.google.com/maps/place//data=!4m2!3...  ...
# 36  https://www.google.com/maps/place//data=!4m2!3...  ...
# 57  https://www.google.com/maps/place//data=!4m2!3...  ...
#
#    MISC.Lodging options                            MISC.Offerings  \
# 2                    []                            [Comfort food]
# 6                    []  [Comfort food, Quick bite, Small plates]
# 8                    []                                        []
# 36                 None                                      None
# 57                   []                                        []
#
#    MISC.Payments MISC.Planning              MISC.Popular for MISC.Recycling  \
# 2             []            []                            []             []
# 6             []            []  [Lunch, Dinner, Solo dining]             []
# 8             []            []                            []             []
# 36          None          None                          None           None
# 57            []            []                            []             []
#
#                                  MISC.Service options postal_code  \
# 2                        [Takeout, Dine-in, Delivery]    CA 90005
# 6   [Outdoor seating, Curbside pickup, No-contact ...    CA 90638
# 8                                          [Delivery]    IA 50263
# 36                                               None    TX 75041
# 57           [No-contact delivery, Delivery, Takeout]    PA 18042
#
#             city      number_and_street
# 2    Los Angeles      761 S Vermont Ave
# 6      La Mirada   12740 La Mirada Blvd
# 8         Waukee      85 NE Dartmoor Dr
# 36       Garland       3838 W Miller Rd
# 57        Easton     148 W St Joseph St
#
# [5 rows x 31 columns]

# %%
reducido = reducido.drop_duplicates(subset='gmap_id')
reducido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 324338 entries, 2 to 3025006
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   name                    324338 non-null  object
#  1   gmap_id                 324338 non-null  object
#  2   description             88132 non-null   object
#  3   latitude                324338 non-null  float64
#  4   longitude               324338 non-null  float64
#  5   category                324338 non-null  object
#  6   avg_rating              324338 non-null  float64
#  7   num_of_reviews          324338 non-null  int64
#  8   relative_results        271607 non-null  object
#  9   url                     324338 non-null  object
#  10  MISC.Accessibility      310481 non-null  object
#  11  MISC.Activities         310481 non-null  object
#  12  MISC.Amenities          310481 non-null  object
#  13  MISC.Atmosphere         310481 non-null  object
#  14  MISC.Crowd              310481 non-null  object
#  15  MISC.Dining options     310481 non-null  object
#  16  MISC.From the business  310481 non-null  object
#  17  MISC.Getting here       310481 non-null  object
#  18  MISC.Health & safety    310481 non-null  object
#  19  MISC.Health and safety  310481 non-null  object
#  20  MISC.Highlights         310481 non-null  object
#  21  MISC.Lodging options    310481 non-null  object
#  22  MISC.Offerings          310481 non-null  object
#  23  MISC.Payments           310481 non-null  object
#  24  MISC.Planning           310481 non-null  object
#  25  MISC.Popular for        310481 non-null  object
#  26  MISC.Recycling          310481 non-null  object
#  27  MISC.Service options    310481 non-null  object
#  28  postal_code             321898 non-null  object
#  29  city                    321896 non-null  object
#  30  number_and_street       321848 non-null  object
# dtypes: float64(3), int64(1), object(27)
# memory usage: 79.2+ MB

# %% [markdown]
# Description tiene solo 27% de datos no nulos

# %%
df = pd.read_parquet('C:/Users/eduen/Desktop/PF_Yelp-Maps_DS-04pt/metadata_google_maps.parquet')
df.head()
# Out:
#                                      name  \
# 2                            San Soo Dang
# 6                            Vons Chicken
# 8   Sweet Rewards Gluten Free Bakery, LLC
# 36                     Luminous Logistics
# 57                     Primo Pizza & Subs
#
#                                   gmap_id description   latitude   longitude  \
# 2   0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 6   0x80dd2b4c8555edb7:0xfc33d65c4bdbef42        None  33.916402 -118.010855
# 8    0x87ec235c54d25b31:0x3b75fb5facc602f        None  41.616079  -93.865487
# 36  0x864ea0993bffffff:0xb50b5bb2fccf9d9b        None  32.893678  -96.688611
# 57  0x89c46d5e4554eae1:0xa2f8b211524ca29a        None  40.682177  -75.209820
#
#                                 category  avg_rating  num_of_reviews  \
# 2                  ['Korean restaurant']         4.4              18
# 6                         ['Restaurant']         4.5              18
# 8   ['Bakery', 'Health food restaurant']         4.7              21
# 36                  ['Delivery service']         2.3               8
# 57                    ['Pizza delivery']         4.5              25
#
#                                      relative_results  \
# 2   [0x80c2c78249aba68f:0x35bf16ce61be751d, 0x80c2...
# 6                                                None
# 8   [0x87ee974869295555:0x95f310d065882c9b, 0x87ec...
# 36  [0x864ea09938bb619f:0x1b6902de2a2f3f96, 0x864e...
# 57  [0x89c46c56cac9c661:0xdc9d0dd3f2b203ae, 0x89c4...
#
#                                                   url  ...  \
# 2   https://www.google.com/maps/place//data=!4m2!3...  ...
# 6   https://www.google.com/maps/place//data=!4m2!3...  ...
# 8   https://www.google.com/maps/place//data=!4m2!3...  ...
# 36  https://www.google.com/maps/place//data=!4m2!3...  ...
# 57  https://www.google.com/maps/place//data=!4m2!3...  ...
#
#    MISC.Lodging options                            MISC.Offerings  \
# 2                    []                            [Comfort food]
# 6                    []  [Comfort food, Quick bite, Small plates]
# 8                    []                                        []
# 36                 None                                      None
# 57                   []                                        []
#
#    MISC.Payments MISC.Planning              MISC.Popular for MISC.Recycling  \
# 2             []            []                            []             []
# 6             []            []  [Lunch, Dinner, Solo dining]             []
# 8             []            []                            []             []
# 36          None          None                          None           None
# 57            []            []                            []             []
#
#                                  MISC.Service options postal_code  \
# 2                        [Takeout, Dine-in, Delivery]    CA 90005
# 6   [Outdoor seating, Curbside pickup, No-contact ...    CA 90638
# 8                                          [Delivery]    IA 50263
# 36                                               None    TX 75041
# 57           [No-contact delivery, Delivery, Takeout]    PA 18042
#
#             city      number_and_street
# 2    Los Angeles      761 S Vermont Ave
# 6      La Mirada   12740 La Mirada Blvd
# 8         Waukee      85 NE Dartmoor Dr
# 36       Garland       3838 W Miller Rd
# 57        Easton     148 W St Joseph St
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 337009 entries, 2 to 3025006
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   name                    337009 non-null  object
#  1   gmap_id                 337009 non-null  object
#  2   description             90321 non-null   object
#  3   latitude                337009 non-null  float64
#  4   longitude               337009 non-null  float64
#  5   category                337009 non-null  object
#  6   avg_rating              337009 non-null  float64
#  7   num_of_reviews          337009 non-null  int64
#  8   relative_results        282436 non-null  object
#  9   url                     337009 non-null  object
#  10  MISC.Accessibility      322794 non-null  object
#  11  MISC.Activities         322794 non-null  object
#  12  MISC.Amenities          322794 non-null  object
#  13  MISC.Atmosphere         322794 non-null  object
#  14  MISC.Crowd              322794 non-null  object
#  15  MISC.Dining options     322794 non-null  object
#  16  MISC.From the business  322794 non-null  object
#  17  MISC.Getting here       322794 non-null  object
#  18  MISC.Health & safety    322794 non-null  object
#  19  MISC.Health and safety  322794 non-null  object
#  20  MISC.Highlights         322794 non-null  object
#  21  MISC.Lodging options    322794 non-null  object
#  22  MISC.Offerings          322794 non-null  object
#  23  MISC.Payments           322794 non-null  object
#  24  MISC.Planning           322794 non-null  object
#  25  MISC.Popular for        322794 non-null  object
#  26  MISC.Recycling          322794 non-null  object
#  27  MISC.Service options    322794 non-null  object
#  28  postal_code             334148 non-null  object
#  29  city                    334146 non-null  object
#  30  number_and_street       334096 non-null  object
# dtypes: float64(3), int64(1), object(27)
# memory usage: 82.3+ MB
